# %%
with open("importance_df.pkl", "rb") as f:
    data = pickle.load(f)

importance_df = data["importance_df"]
importance_df_norm = data["importance_df_norm"]
importance_df_2 = data["importance_df_2"]
